# %%
from mlxtend.plotting import plot_decision_regions
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Charger ke dataset
IMDB_data = pd.read_csv ("./drive/MyDrive/IMDB Dataset.csv") 

#Imoression des 5 premieres lignes
IMDB_data.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
IMDB_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     50000 non-null  object
#  1   sentiment  50000 non-null  object
# dtypes: object(2)
# memory usage: 781.4+ KB

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
cinema=vectorizer.fit_transform(IMDB_data["review"])

# %%
IMDB_data.describe()
# Out:
#                                                    review sentiment
# count                                               50000     50000
# unique                                              49581         2
# top     Loved today's show!!! It was a variety and not...  positive
# freq                                                    5     25000

# %%
X = cinema
y = IMDB_data.sentiment

# %%
X
# Out:
# <50000x101895 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6826196 stored elements in Compressed Sparse Row format>

# %%
y
# Out:
# 0        positive
# 1        positive
# 2        positive
# 3        negative
# 4        positive
#            ...
# 49995    positive
# 49996    negative
# 49997    negative
# 49998    negative
# 49999    negative
# Name: sentiment, Length: 50000, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=42)

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train , y_train)

# %%
y_pred = clf.predict(X_test)

# %% [markdown]
# Exercice: prédire qui doit être conviqué en priorité pour une détection du diabete

# %%
 from sklearn.metrics import accuracy_score
 accuracy_score(y_test, y_pred)
# Out:
# 0.7140457190856183
